# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ, BasicAer, qiskit
from qiskit.quantum_info import Statevector
from qiskit.circuit.random import random_circuit

from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator

# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2022-01-16 14:08:46,920: Credentials are already in use. The existing account in the session will be replaced.

# %%
qc=random_circuit(2,4)
qc.draw('mpl')
qc.draw('latex')
print(qc)
sv=Statevector.from_label('00')
print(sv)
ev=sv.evolve(qc)
print(ev)
plot_state_city(ev)
ev.draw('city')
# Out:
#          ┌───┐              ┌─────┐                         ┌───┐
# q_0: ────┤ H ├──────────────┤ Sdg ├────────────■────────────┤ H ├
#      ┌───┴───┴───┐┌─────────┴─────┴──────────┐ │ZZ(0.75279) └─┬─┘
# q_1: ┤ Rz(5.539) ├┤ U3(4.219,4.4258,0.26609) ├─■──────────────■──
#      └───────────┘└──────────────────────────┘
# Statevector([1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#             dims=(2, 2))
# Statevector([ 0.36275663-0.00156329j,  0.24686773-0.26580283j,
#               0.21989836+0.26111207j, -0.60240902+0.50732528j],
#             dims=(2, 2))

# %%
ev.draw('hinton')

# %%
qc.draw('mpl')

# %%
qc.draw('latex')
# Out:
# <PIL.Image.Image image mode=RGB size=593x70 at 0x7F9B34EC6310>

# %%
backend=BasicAer.get_backend('statevector_simulator')
job=qiskit.execute(qc,backend,shots=1024)
result=job.result()
sv=result.get_statevector()
plot_state_city(sv)

# %%
sv.draw('hinton')
# Out:
# Traceback (most recent call last):
#   Input In [20] in <module>
#     sv.draw('hinton')
# AttributeError: 'numpy.ndarray' object has no attribute 'draw'
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=AttributeError: 'numpy.ndarray' object has no attribute 'draw'" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>
