# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ, qiskit, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator

# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2022-01-20 05:21:57,770: Credentials are already in use. The existing account in the session will be replaced.

# %%
qc=QuantumCircuit(2)
qc.h(0)
qc.x(1)
qc.cx(0,1)
qc.measure_all()
job=qiskit.execute(qc,qiskit.BasicAer.get_backend('qasm_simulator'))
print(job.result().get_counts())
# Out:
# {'10': 522, '01': 502}

# %%
qc.draw()

# %%
plot_histogram(job.result().get_counts())

# %%
qc1=QuantumCircuit(2,2)
qc1.h(0)
qc1.x(1)
qc1.cx(0,1)
simulator=Aer.get_backend('statevector_simulator')
qobj=assemble(qc1)
result=simulator.run(qobj).result()
output_state=result.get_statevector(qc1)
print(output_state)
plot_histogram(result.get_counts())
# Out:
# Statevector([0.        +0.j, 0.70710678+0.j, 0.70710678+0.j,
#              0.        +0.j],
#             dims=(2, 2))

# %%
plot_bloch_multivector(output_state)

# %%
plot_state_city(output_state)

# %%
output_state.draw('hinton')

# %%
plot_state_paulivec(output_state)
